# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)


FOLDERNAME = 'Project 2'
assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# Out:
# Mounted at /content/drive

# %%
#navigating to Project 2 directory
# !pwd
# Out:
# /content

# %%
cd /content/drive/MyDrive/Project 2
# Out:
# /content/drive/MyDrive/Project 2

# %% [markdown]
# **Base Model - ResNet18**
#
# To run the base model, execute the following cell.

# %%
# !python main.py
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 403ms | Tot: 23s128ms | Loss: 2.193 | Acc: 25.060% (12530/50000) 196/196
#  [===============================================================>.]  Step: 81ms | Tot: 2s479ms | Loss: 1.703 | Acc: 36.090% (3609/10000) 40/40
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 38ms | Tot: 23s792ms | Loss: 1.594 | Acc: 40.572% (20286/50000) 196/196
#  [===============================================================>.]  Step: 7ms | Tot: 2s394ms | Loss: 1.420 | Acc: 47.510% (4751/10000) 40/40
# Saving..
#
# Epoch: 2
#  [================================================================>]  Step: 38ms | Tot: 22s826ms | Loss: 1.341 | Acc: 51.202% (25601/50000) 196/196
# ...

# %% [markdown]
# One shot pruning at 90%, 75%, and 50% sparity

# %%
# run on 90% sparse model (one shot pruning)
# !python main.py -pos -pa 0.90

# %%
# !python main.py -pos -pa 0.75
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# Perform one shot pruning and retraining
#
# Epoch: 188
#  [================================================================>]  Step: 415ms | Tot: 22s928ms | Loss: 0.508 | Acc: 82.796% (41398/50000) 196/196
#  [===============================================================>.]  Step: 76ms | Tot: 2s390ms | Loss: 0.865 | Acc: 73.010% (7301/10000) 40/40
# Saving..
# Global sparsity: 75.00%
#
# Epoch: 189
#  [================================================================>]  Step: 38ms | Tot: 23s303ms | Loss: 0.326 | Acc: 88.800% (44400/50000) 196/196
#  [===============================================================>.]  Step: 11ms | Tot: 2s436ms | Loss: 0.422 | Acc: 86.250% (8625/10000) 40/40
# Saving..
# Global sparsity: 75.00%
#
# Epoch: 190
# ...

# %%
# !python main.py -pos -pa 0.50
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# Perform one shot pruning and retraining
#
# Epoch: 188
#  [================================================================>]  Step: 397ms | Tot: 20s56ms | Loss: 0.615 | Acc: 79.040% (39520/50000) 196/196
#  [===============================================================>.]  Step: 68ms | Tot: 1s872ms | Loss: 1.106 | Acc: 67.390% (6739/10000) 40/40
# Saving..
# Global sparsity: 50.00%
#
# Epoch: 189
#  [================================================================>]  Step: 39ms | Tot: 20s24ms | Loss: 0.442 | Acc: 84.966% (42483/50000) 196/196
#  [===============================================================>.]  Step: 8ms | Tot: 1s779ms | Loss: 0.630 | Acc: 79.710% (7971/10000) 40/40
# Saving..
# Global sparsity: 50.00%
#
# Epoch: 190
# ...

# %% [markdown]
# Iterative pruning

# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive/Project\ 2
# Out:
# /content/drive/MyDrive/Project 2

# %%
# !python main.py -pit -pa 0.5
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 421ms | Tot: 22s650ms | Loss: 1.910 | Acc: 31.568% (15784/50000) 196/196
#  [===============================================================>.]  Step: 80ms | Tot: 2s424ms | Loss: 1.573 | Acc: 41.900% (4190/10000) 40/40
# Saving..
# Global sparsity: 12.50%
#
# Epoch: 1
#  [================================================================>]  Step: 38ms | Tot: 22s702ms | Loss: 1.412 | Acc: 47.774% (23887/50000) 196/196
#  [===============================================================>.]  Step: 8ms | Tot: 2s348ms | Loss: 1.525 | Acc: 48.620% (4862/10000) 40/40
# Saving..
# Global sparsity: 12.50%
#
# Epoch: 2
#  [================================================================>]  Step: 37ms | Tot: 22s728ms | Loss: 1.175 | Acc: 57.710% (28855/50000) 196/196
# ...

# %%
# !python main.py -pit -pa 0.75
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 353ms | Tot: 19s906ms | Loss: 1.931 | Acc: 31.222% (15611/50000) 196/196
#  [===============================================================>.]  Step: 85ms | Tot: 1s895ms | Loss: 1.565 | Acc: 43.050% (4305/10000) 40/40
# Saving..
# Global sparsity: 18.75%
#
# Epoch: 1
#  [================================================================>]  Step: 42ms | Tot: 19s691ms | Loss: 1.415 | Acc: 48.058% (24029/50000) 196/196
#  [===============================================================>.]  Step: 6ms | Tot: 1s800ms | Loss: 1.275 | Acc: 53.540% (5354/10000) 40/40
# Saving..
# Global sparsity: 18.75%
#
# Epoch: 2
#  [================================================================>]  Step: 37ms | Tot: 19s860ms | Loss: 1.152 | Acc: 58.436% (29218/50000) 196/196
# ...

# %%
# !python main.py -pit -pa 0.9
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 368ms | Tot: 23s40ms | Loss: 2.343 | Acc: 21.936% (10968/50000) 196/196
#  [===============================================================>.]  Step: 90ms | Tot: 2s498ms | Loss: 1.770 | Acc: 34.290% (3429/10000) 40/40
# Saving..
# Global sparsity: 22.50%
#
# Epoch: 1
#  [================================================================>]  Step: 38ms | Tot: 23s143ms | Loss: 1.631 | Acc: 39.332% (19666/50000) 196/196
#  [===============================================================>.]  Step: 8ms | Tot: 2s440ms | Loss: 1.666 | Acc: 39.410% (3941/10000) 40/40
# Saving..
# Global sparsity: 22.50%
#
# Epoch: 2
#  [================================================================>]  Step: 37ms | Tot: 23s224ms | Loss: 1.401 | Acc: 48.666% (24333/50000) 196/196
# ...
