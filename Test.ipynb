# %%
# this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FOLDERNAME = 'Project 2'
assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Project\ 2
# Out:
# /content/drive/MyDrive/Project 2

# %%
# !python test.py
# Out:
# Files already downloaded and verified
# Accuracy for no pruning model :95.29
# Accuracy for one-shot pruning 90% sparsity :92.36
# Accuracy for one-shot pruning 75% sparsity :92.26
# Accuracy for one-shot pruning 50% sparsity :92.36
# Accuracy for iterative pruning 90% sparsity :91.16
# Accuracy for iterative pruning 75% sparsity :91.1
# Accuracy for iterative pruning 50% sparsity :90.99
